# %%
import pandas as pd

# %%
jan=pd.read_csv("Sales_January_2019.csv")
feb=pd.read_csv("Sales_February_2019.csv")
mar=pd.read_csv("Sales_March_2019.csv")
apr=pd.read_csv("Sales_April_2019.csv")
may=pd.read_csv("Sales_May_2019.csv")
jun=pd.read_csv("Sales_June_2019.csv")
jul=pd.read_csv("Sales_July_2019.csv")
aug=pd.read_csv("Sales_August_2019.csv")
sept=pd.read_csv("Sales_September_2019.csv")
october=pd.read_csv("Sales_October_2019.csv")
nov=pd.read_csv("Sales_November_2019.csv")
dec=pd.read_csv("Sales_December_2019.csv")

# %% [markdown]
# ## Merging the files

# %%
lst=[jan,feb,mar,apr,may,jun,jul,aug,sept,october,nov,dec]
all_months=pd.concat(lst)

# %%
all_months
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       141234                      iPhone                1        700
# 1       141235    Lightning Charging Cable                1      14.95
# 2       141236            Wired Headphones                2      11.99
# 3       141237            27in FHD Monitor                1     149.99
# 4       141238            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                        Purchase Address
# ...

# %%
all_months.to_csv("all_months.csv",index=False)

# %%
all_months=pd.read_csv("all_months.csv")
all_months.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %% [markdown]
# ## Which was the best month for sales and how much was earned during that month

# %%
all_months.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
#using string methods on dataframe

# %%
#txt = "apple#banana#cherry#orange"
#x = txt.split("#", 1)
#['apple', 'banana#cherry#orange']
all_months[['month','rest']]=all_months['Order Date'].str.split('/',n=1,expand=True)

# %%
all_months.drop(columns='rest',inplace=True)

# %%
all_months
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   319666    Lightning Charging Cable                1      14.95
# 186846   319667       AA Batteries (4-pack)                2       3.84
# 186847   319668             Vareebadd Phone                1        400
# 186848   319669            Wired Headphones                1      11.99
# 186849   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address month
# ...

# %%
all_months.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# month               object
# dtype: object

# %%
all_months[all_months['Quantity Ordered']=='Quantity Ordered']
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 1073    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1102    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1194    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1897    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2463    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 184931  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185070  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185481  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185925  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185955  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address       month
# 1073    Purchase Address  Order Date
# 1102    Purchase Address  Order Date
# ...

# %%
all_months = all_months.drop(all_months[all_months['Quantity Ordered'] == 'Quantity Ordered'].index)

# %%
all_months['Price Each'].value_counts()
all_months['Quantity Ordered'].value_counts()
# Out:
# 1    168552
# 2     13324
# 3      2920
# 4       806
# 5       236
# 6        80
# 7        24
# 8         5
# 9         3
# Name: Quantity Ordered, dtype: int64

# %%
all_months=all_months.astype({'Quantity Ordered':'float','Price Each':'float'})

# %%
all_months.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186495 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  float64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   month             185950 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 11.4+ MB

# %% [markdown]
# ## Sales column

# %%
all_months["Sales"]=all_months['Price Each']*all_months['Quantity Ordered']

# %%
all_months
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone               1.0      700.00
# 1        141235    Lightning Charging Cable               1.0       14.95
# 2        141236            Wired Headphones               2.0       11.99
# 3        141237            27in FHD Monitor               1.0      149.99
# 4        141238            Wired Headphones               1.0       11.99
# ...         ...                         ...               ...         ...
# 186845   319666    Lightning Charging Cable               1.0       14.95
# 186846   319667       AA Batteries (4-pack)               2.0        3.84
# 186847   319668             Vareebadd Phone               1.0      400.00
# 186848   319669            Wired Headphones               1.0       11.99
# 186849   319670  Bose SoundSport Headphones               1.0       99.99
#
#             Order Date                        Purchase Address month   Sales
# ...

# %% [markdown]
# ## Delete null values

# %%
all_months[all_months.isna().any(axis=1)]
# Out:
#        Order ID Product  Quantity Ordered  Price Each Order Date  \
# 664         NaN     NaN               NaN         NaN        NaN
# 678         NaN     NaN               NaN         NaN        NaN
# 797         NaN     NaN               NaN         NaN        NaN
# 876         NaN     NaN               NaN         NaN        NaN
# 1299        NaN     NaN               NaN         NaN        NaN
# ...         ...     ...               ...         ...        ...
# 184678      NaN     NaN               NaN         NaN        NaN
# 184695      NaN     NaN               NaN         NaN        NaN
# 185042      NaN     NaN               NaN         NaN        NaN
# 185729      NaN     NaN               NaN         NaN        NaN
# 186463      NaN     NaN               NaN         NaN        NaN
#
#        Purchase Address month  Sales
# 664                 NaN   NaN    NaN
# 678                 NaN   NaN    NaN
# 797                 NaN   NaN    NaN
# ...

# %%
all_months=all_months.dropna(how='all')

# %%
all_months.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  float64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   month             185950 non-null  object
#  7   Sales             185950 non-null  float64
# dtypes: float64(3), object(5)
# memory usage: 12.8+ MB

# %% [markdown]
# ## To view the sum of sales

# %%
print("Sales for January:",all_months[all_months['month']=='01']['Sales'].sum())
print("Sales for February:",all_months[all_months['month']=='02']['Sales'].sum())
print("Sales for March: ",all_months[all_months['month']=='03']['Sales'].sum())
print("Sales for April:",all_months[all_months['month']=='04']['Sales'].sum())
print("Sales for May:",all_months[all_months['month']=='05']['Sales'].sum())
print("Sales for June:",all_months[all_months['month']=='06']['Sales'].sum())
print("Sales for July:",all_months[all_months['month']=='07']['Sales'].sum())
print("Sales for August:",all_months[all_months['month']=='08']['Sales'].sum())
print("Sales for September:",all_months[all_months['month']=='09']['Sales'].sum())
print("Sales for October:",all_months[all_months['month']=='10']['Sales'].sum())
print("Sales for November:",all_months[all_months['month']=='11']['Sales'].sum())
print("Sales for December:",all_months[all_months['month']=='12']['Sales'].sum())
# Out:
# Sales for January: 1822256.73
# Sales for February: 2202022.42
# Sales for March:  2807100.38
# Sales for April: 3390670.2399999998
# Sales for May: 3152606.7499999995
# Sales for June: 2577802.26
# Sales for July: 2647775.76
# Sales for August: 2244467.88
# Sales for September: 2097560.13
# Sales for October: 3736726.8799999994
# Sales for November: 3199603.1999999997
# Sales for December: 4613443.339999999

# %% [markdown]
# ### Or

# %%
result=all_months.groupby(['month']).sum()
result
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2620\848911909.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   result=all_months.groupby(['month']).sum()
#        Quantity Ordered  Price Each       Sales
# month
# 01              10903.0  1811768.38  1822256.73
# 02              13449.0  2188884.72  2202022.42
# 03              17005.0  2791207.83  2807100.38
# 04              20558.0  3367671.02  3390670.24
# 05              18667.0  3135125.13  3152606.75
# 06              15253.0  2562025.61  2577802.26
# 07              16072.0  2632539.56  2647775.76
# 08              13448.0  2230345.42  2244467.88
# 09              13109.0  2084992.09  2097560.13
# 10              22703.0  3715554.83  3736726.88
# 11              19798.0  3180600.68  3199603.20
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(result.index.values,result['Sales'],color='green')
plt.xlabel("Months")
plt.ylabel("Sales (in million)")
# Out:
# Text(0, 0.5, 'Sales (in million)')

# %% [markdown]
# ## Which city has the highest number of sales

# %%
all_months[['address','City','address1']]=all_months['Purchase Address'].str.split(',',expand=True)
all_months.drop(columns=['address','address1'],inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2620\3317067109.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_months[['address','City','address1']]=all_months['Purchase Address'].str.split(',',expand=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2620\3317067109.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_months[['address','City','address1']]=all_months['Purchase Address'].str.split(',',expand=True)
# ...

# %%
all_months
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone               1.0      700.00
# 1        141235    Lightning Charging Cable               1.0       14.95
# 2        141236            Wired Headphones               2.0       11.99
# 3        141237            27in FHD Monitor               1.0      149.99
# 4        141238            Wired Headphones               1.0       11.99
# ...         ...                         ...               ...         ...
# 186845   319666    Lightning Charging Cable               1.0       14.95
# 186846   319667       AA Batteries (4-pack)               2.0        3.84
# 186847   319668             Vareebadd Phone               1.0      400.00
# 186848   319669            Wired Headphones               1.0       11.99
# 186849   319670  Bose SoundSport Headphones               1.0       99.99
#
#             Order Date                        Purchase Address month   Sales  \
# ...

# %%
city=all_months.groupby(['City']).sum().sort_values(by='Sales')
city
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2620\1021652175.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   city=all_months.groupby(['City']).sum().sort_values(by='Sales')
#                 Quantity Ordered  Price Each       Sales
# City
#  Austin                  11153.0  1809873.61  1819581.75
#  Portland                14053.0  2307747.47  2320490.61
#  Seattle                 16553.0  2733296.01  2747755.48
#  Dallas                  16730.0  2752627.82  2767975.40
#  Atlanta                 16602.0  2779908.20  2795498.58
#  Boston                  22528.0  3637409.77  3661642.01
#  New York City           27932.0  4635370.83  4664317.43
#  Los Angeles             33289.0  5421435.23  5452570.80
#  San Francisco           50239.0  8211461.74  8262203.91

# %%
import seaborn as sns

# %%
sns.barplot(x='Sales',data=city,y=city.index)
plt.xlabel('Sales (in Million)')
# Out:
# Text(0.5, 0, 'Sales (in Million)')

# %% [markdown]
# ## What time should we display advertisements to maximise likelihood of customers buying the product

# %%
all_months['Order Date']=pd.to_datetime(all_months['Order Date'])
all_months['Hour']=all_months['Order Date'].dt.hour
all_months
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2620\3658165615.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_months['Order Date']=pd.to_datetime(all_months['Order Date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_2620\3658165615.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_months['Hour']=all_months['Order Date'].dt.hour
#        Order ID                     Product  Quantity Ordered  Price Each  \
# ...

# %%
all_months.groupby(['Hour']).count()
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hour
# 0         3910     3910              3910        3910        3910
# 1         2350     2350              2350        2350        2350
# 2         1243     1243              1243        1243        1243
# 3          831      831               831         831         831
# 4          854      854               854         854         854
# 5         1321     1321              1321        1321        1321
# 6         2482     2482              2482        2482        2482
# 7         4011     4011              4011        4011        4011
# 8         6256     6256              6256        6256        6256
# 9         8748     8748              8748        8748        8748
# 10       10944    10944             10944       10944       10944
# 11       12411    12411             12411       12411       12411
# 12       12587    12587             12587       12587       12587
# ...

# %%
#to draw line chart in python we use plt.plot
#You can use the plot(x,y) method to create a line chart.
best_time=all_months.groupby(['Hour']).count()
plt.plot(best_time)
plt.xticks(best_time.index.values)
plt.grid()
plt.xlabel("Time")
plt.ylabel("No. of Orders")
# Out:
# Text(0, 0.5, 'No. of Orders')

# %% [markdown]
# ## What product are most often sold together

# %%
#this means that when products have the same order ID they are sold together
all_months['Order ID'].value_counts()
# Out:
# 160873    5
# 312462    4
# 242936    4
# 235798    4
# 165665    4
#          ..
# 201973    1
# 201974    1
# 201975    1
# 201976    1
# 319670    1
# Name: Order ID, Length: 178437, dtype: int64

# %%
#The join() method takes all items in an iterable and joins them into one string.
#myTuple = ("John", "Peter", "Vicky")
#x = "#".join(myTuple)
# John#Peter#Vicky
#Input:
#apply implicitly passes all the columns for each group as a DataFrame to the custom function.
#while transform passes each column for each group individually as a Series to the custom function.
#So, transform works on just one Series at a time and apply works on the entire DataFrame at once.
def join(x):
    return ','.join(x)
all_months['Grouped']=all_months['Product'].groupby(all_months['Order ID']).transform(join)
all_months
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2620\3260163375.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_months['Grouped']=all_months['Product'].groupby(all_months['Order ID']).transform(join)
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone               1.0      700.00
# 1        141235    Lightning Charging Cable               1.0       14.95
# 2        141236            Wired Headphones               2.0       11.99
# 3        141237            27in FHD Monitor               1.0      149.99
# 4        141238            Wired Headphones               1.0       11.99
# ...         ...                         ...               ...         ...
# ...

# %%
all_months[all_months['Order ID']=='235798']
# Out:
#       Order ID               Product  Quantity Ordered  Price Each  \
# 99084   235798          Google Phone               1.0      600.00
# 99085   235798  USB-C Charging Cable               1.0       11.95
# 99086   235798      Wired Headphones               1.0       11.99
# 99087   235798      27in FHD Monitor               1.0      149.99
#
#                Order Date                       Purchase Address month  \
# 99084 2019-07-22 16:58:00  205 Dogwood St, Los Angeles, CA 90001    07
# 99085 2019-07-22 16:58:00  205 Dogwood St, Los Angeles, CA 90001    07
# 99086 2019-07-22 16:58:00  205 Dogwood St, Los Angeles, CA 90001    07
# 99087 2019-07-22 16:58:00  205 Dogwood St, Los Angeles, CA 90001    07
#
#         Sales          City  Hour  \
# 99084  600.00   Los Angeles    16
# 99085   11.95   Los Angeles    16
# 99086   11.99   Los Angeles    16
# 99087  149.99   Los Angeles    16
#
#                                                  Grouped
# ...

# %%
order=all_months[['Order ID','Grouped']]
order=order.drop_duplicates()

# %%
order
# Out:
#        Order ID                     Grouped
# 0        141234                      iPhone
# 1        141235    Lightning Charging Cable
# 2        141236            Wired Headphones
# 3        141237            27in FHD Monitor
# 4        141238            Wired Headphones
# ...         ...                         ...
# 186845   319666    Lightning Charging Cable
# 186846   319667       AA Batteries (4-pack)
# 186847   319668             Vareebadd Phone
# 186848   319669            Wired Headphones
# 186849   319670  Bose SoundSport Headphones
#
# [178437 rows x 2 columns]

# %%
order['Grouped'].value_counts()
#order[order['Grouped']=='Google Phone,USB-C Charging Cable,Wired Headphones,27in FHD Monitor']
# Out:
# Lightning Charging Cable                                                       19831
# AAA Batteries (4-pack)                                                         19826
# AA Batteries (4-pack)                                                          19809
# USB-C Charging Cable                                                           19792
# Wired Headphones                                                               17208
#                                                                                ...
# iPhone,Google Phone                                                                1
# LG Dryer,Flatscreen TV                                                             1
# Vareebadd Phone,27in FHD Monitor                                                   1
# iPhone,Lightning Charging Cable,Wired Headphones,USB-C Charging Cable              1
# Google Phone,USB-C Charging Cable,Wired Headphones,Apple Airpods Headphones        1
# Name: Grouped, Length: 385, dtype: int64

# %%
#Python’s Itertool is a module that provides various functions that work on iterators to produce complex iterators. 
from itertools import combinations
from collections import Counter
#A Counter is a subclass of dict.

# %%
#txt = "hello, my name is Peter, I am 26 years old"
#x = txt.split(", ")
#['hello', 'my name is Peter', 'I am 26 years old']
count=Counter()
for row in order['Grouped']:
    row_list=row.split(",")
    #count.update(data)
    count.update(Counter(combinations(row_list,3)))
count.most_common(10)
# Out:
# [(('Google Phone', 'USB-C Charging Cable', 'Wired Headphones'), 87),
#  (('iPhone', 'Lightning Charging Cable', 'Wired Headphones'), 62),
#  (('iPhone', 'Lightning Charging Cable', 'Apple Airpods Headphones'), 47),
#  (('Google Phone', 'USB-C Charging Cable', 'Bose SoundSport Headphones'), 35),
#  (('Vareebadd Phone', 'USB-C Charging Cable', 'Wired Headphones'), 33),
#  (('iPhone', 'Apple Airpods Headphones', 'Wired Headphones'), 27),
#  (('Google Phone', 'Bose SoundSport Headphones', 'Wired Headphones'), 24),
#  (('Vareebadd Phone', 'USB-C Charging Cable', 'Bose SoundSport Headphones'),
#   16),
#  (('Vareebadd Phone', 'Bose SoundSport Headphones', 'Wired Headphones'), 5),
#  (('USB-C Charging Cable', 'Bose SoundSport Headphones', 'Wired Headphones'),
#   5)]

# %% [markdown]
# ### Or

# %%
order1=all_months[['Order ID','Grouped']]
order1
# Out:
#        Order ID                     Grouped
# 0        141234                      iPhone
# 1        141235    Lightning Charging Cable
# 2        141236            Wired Headphones
# 3        141237            27in FHD Monitor
# 4        141238            Wired Headphones
# ...         ...                         ...
# 186845   319666    Lightning Charging Cable
# 186846   319667       AA Batteries (4-pack)
# 186847   319668             Vareebadd Phone
# 186848   319669            Wired Headphones
# 186849   319670  Bose SoundSport Headphones
#
# [185950 rows x 2 columns]

# %%
Counter([
    t for _, d in order1.groupby('Order ID').Grouped
    for t in combinations(d,3)
]).most_common(10)
# Out:
# [(('Google Phone,USB-C Charging Cable,Wired Headphones',
#    'Google Phone,USB-C Charging Cable,Wired Headphones',
#    'Google Phone,USB-C Charging Cable,Wired Headphones'),
#   77),
#  (('iPhone,Lightning Charging Cable,Wired Headphones',
#    'iPhone,Lightning Charging Cable,Wired Headphones',
#    'iPhone,Lightning Charging Cable,Wired Headphones'),
#   56),
#  (('iPhone,Lightning Charging Cable,Apple Airpods Headphones',
#    'iPhone,Lightning Charging Cable,Apple Airpods Headphones',
#    'iPhone,Lightning Charging Cable,Apple Airpods Headphones'),
#   43),
#  (('Vareebadd Phone,USB-C Charging Cable,Wired Headphones',
#    'Vareebadd Phone,USB-C Charging Cable,Wired Headphones',
#    'Vareebadd Phone,USB-C Charging Cable,Wired Headphones'),
#   31),
#  (('Google Phone,USB-C Charging Cable,Bose SoundSport Headphones',
#    'Google Phone,USB-C Charging Cable,Bose SoundSport Headphones',
#    'Google Phone,USB-C Charging Cable,Bose SoundSport Headphones'),
#   31),
# ...

# %%
all_months[all_months['Grouped']=='iPhone,Lightning Charging Cable,Apple Airpods Headphones']
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 1878     143021                    iPhone               1.0      700.00
# 1879     143021  Lightning Charging Cable               1.0       14.95
# 1880     143021  Apple Airpods Headphones               1.0      150.00
# 10193    150951                    iPhone               1.0      700.00
# 10194    150951  Lightning Charging Cable               1.0       14.95
# ...         ...                       ...               ...         ...
# 166115   299830  Lightning Charging Cable               1.0       14.95
# 166116   299830  Apple Airpods Headphones               1.0      150.00
# 183448   316412                    iPhone               1.0      700.00
# 183449   316412  Lightning Charging Cable               1.0       14.95
# 183450   316412  Apple Airpods Headphones               1.0      150.00
#
#                 Order Date                        Purchase Address month  \
# ...

# %% [markdown]
# ## What product sold the most? And why

# %%
product_ordered=all_months.groupby(['Product']).sum()
product_ordered
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2620\1465520847.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   product_ordered=all_months.groupby(['Product']).sum()
#                             Quantity Ordered  Price Each       Sales    Hour
# Product
# 20in Monitor                          4129.0   451068.99   454148.71   58764
# 27in 4K Gaming Monitor                6244.0  2429637.70  2435097.56   90916
# 27in FHD Monitor                      7550.0  1125974.93  1132424.50  107540
# 34in Ultrawide Monitor                6199.0  2348718.19  2355558.01   89076
# AA Batteries (4-pack)                27635.0    79015.68   106118.40  298342
# AAA Batteries (4-pack)               31017.0    61716.59    92740.83  297332
# ...

# %%
plt.bar(product_ordered.index.values,product_ordered['Quantity Ordered'],color='red')
plt.xlabel("Products")
plt.xticks(rotation='vertical')
plt.ylabel("Quantity")
# Out:
# Text(0, 0.5, 'Quantity')

# %%
#the quantity sold depends on the price , higher the price lower the same so lets do a price analysis
price=all_months.groupby(['Product']).mean()
price
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2620\692887610.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   price=all_months.groupby(['Product']).mean()
#                             Quantity Ordered  Price Each        Sales  \
# Product
# 20in Monitor                        1.006828      109.99   110.740968
# 27in 4K Gaming Monitor              1.002247      389.99   390.866382
# 27in FHD Monitor                    1.005728      149.99   150.849141
# 34in Ultrawide Monitor              1.002912      379.99   381.096588
# AA Batteries (4-pack)               1.343004        3.84     5.157137
# AAA Batteries (4-pack)              1.502689        2.99     4.493040
# Apple Airpods Headphones            1.007203      150.00   151.080455
# ...

# %%
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(product_ordered.index.values,product_ordered['Quantity Ordered'],color='r')
ax2.plot(product_ordered.index.values,price['Price Each'],'b-')

ax1.set_xlabel('Products')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price', color='b')
ax1.set_xticklabels(labels=product_ordered.index.values,rotation='vertical')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2620\306348239.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels=product_ordered.index.values,rotation='vertical')
